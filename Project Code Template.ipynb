# %% [raw]
# ---
# title: "Project Code"
# subtitle: Team name
# author: Author 1, Author 2, Author 3, and Author 4
# date: 12/09/2025
# number-sections: true
# abstract: _This file contains the code for the project on <>, as part of the STAT303-1-Sec20&21 course in Fall 2024_.
# format:
#   html:
#     toc: true
#     toc-title: Contents
#     self-contained: true
#     font-size: 100%
#     toc-depth: 4
#     mainfont: serif
# jupyter: python3
# ---

# %% [markdown]
# ## Length of the code {-}
# No restriction
#
# **Delete this section from the report, when using this template.**

# %% [markdown]
# ## Data quality check / cleaning / preparation
#
# Put code with comments. The comments should explain the code such that it can be easily understood. You may put text *(in a markdown cell)* before a large chunk of code to explain the overall purpose of the code, if it is not intuitive. **Put the name of the person / persons who contributed to each code chunk / set of code chunks.** An example is given below.

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from shapely.geometry import Point
import geopandas as gpd
from sklearn import metrics
from sklearn import impute

# %matplotlib inline

# %%
#Load in the divvy data - Rebecca Lazarus
april2020 = pd.read_csv("../data/202004-divvy-tripdata.csv")
may2020 = pd.read_csv("../data/202005-divvy-tripdata.csv")
june2020 = pd.read_csv("../data/202006-divvy-tripdata.csv")
july2020 = pd.read_csv("../data/202007-divvy-tripdata.csv")
august2020 = pd.read_csv("../data/202008-divvy-tripdata.csv")
september2020 = pd.read_csv("../data/202009-divvy-tripdata.csv")
october2020 = pd.read_csv("../data/202010-divvy-tripdata.csv")
novemeber2020 = pd.read_csv("../data/202011-divvy-tripdata.csv")
december2020 = pd.read_csv("../data/202012-divvy-tripdata.csv")
january2021 = pd.read_csv("../data/202101-divvy-tripdata.csv")
february2021 = pd.read_csv("../data/202102-divvy-tripdata.csv")
march2021 = pd.read_csv("../data/202103-divvy-tripdata.csv")
april2021 = pd.read_csv("../data/202104-divvy-tripdata.csv")
may2021 = pd.read_csv("../data/202105-divvy-tripdata.csv")
june2021 = pd.read_csv("../data/202106-divvy-tripdata.csv")
july2021 = pd.read_csv("../data/202107-divvy-tripdata.csv")
august2021 = pd.read_csv("../data/202108-divvy-tripdata.csv")
september2021 = pd.read_csv("../data/202109-divvy-tripdata.csv")
october2021 = pd.read_csv("../data/202110-divvy-tripdata.csv")
novemeber2021 = pd.read_csv("../data/202111-divvy-tripdata.csv")
december2021 = pd.read_csv("../data/202112-divvy-tripdata.csv")
january2022 = pd.read_csv("../data/202201-divvy-tripdata.csv")
february2022 = pd.read_csv("../data/202202-divvy-tripdata.csv")
march2022 = pd.read_csv("../data/202203-divvy-tripdata.csv")
april2022 = pd.read_csv("../data/202204-divvy-tripdata.csv")
may2022 = pd.read_csv("../data/202205-divvy-tripdata.csv")
june2022 = pd.read_csv("../data/202206-divvy-tripdata.csv")
july2022 = pd.read_csv("../data/202207-divvy-tripdata.csv")
august2022 = pd.read_csv("../data/202208-divvy-tripdata.csv")
september2022 = pd.read_csv("../data/202209-divvy-tripdata.csv")
october2022 = pd.read_csv("../data/202210-divvy-tripdata.csv")
novemeber2022 = pd.read_csv("../data/202211-divvy-tripdata.csv")
december2022 = pd.read_csv("../data/202212-divvy-tripdata.csv")
january2023 = pd.read_csv("../data/202301-divvy-tripdata.csv")
february2023 = pd.read_csv("../data/202302-divvy-tripdata.csv")
march2023 = pd.read_csv("../data/202303-divvy-tripdata.csv")
april2023 = pd.read_csv("../data/202304-divvy-tripdata.csv")
may2023 = pd.read_csv("../data/202305-divvy-tripdata.csv")
june2023 = pd.read_csv("../data/202306-divvy-tripdata.csv")
july2023 = pd.read_csv("../data/202307-divvy-tripdata.csv")
august2023 = pd.read_csv("../data/202308-divvy-tripdata.csv")
september2023 = pd.read_csv("../data/202309-divvy-tripdata.csv")
october2023 = pd.read_csv("../data/202310-divvy-tripdata.csv")
novemeber2023 = pd.read_csv("../data/202311-divvy-tripdata.csv")
december2023 = pd.read_csv("../data/202312-divvy-tripdata.csv")
january2024 = pd.read_csv("../data/202401-divvy-tripdata.csv")
february2024 = pd.read_csv("../data/202402-divvy-tripdata.csv")
march2024 = pd.read_csv("../data/202403-divvy-tripdata.csv")
april2024 = pd.read_csv("../data/202404-divvy-tripdata.csv")
may2024 = pd.read_csv("../data/202405-divvy-tripdata.csv")
june2024 = pd.read_csv("../data/202406-divvy-tripdata.csv")
july2024 = pd.read_csv("../data/202407-divvy-tripdata.csv")
august2024 = pd.read_csv("../data/202408-divvy-tripdata.csv")
september2024 = pd.read_csv("../data/202409-divvy-tripdata.csv")
october2024 = pd.read_csv("../data/202410-divvy-tripdata.csv")
novemeber2024 = pd.read_csv("../data/202411-divvy-tripdata.csv")
december2024 = pd.read_csv("../data/202412-divvy-tripdata.csv")
january2025 = pd.read_csv("../data/202501-divvy-tripdata.csv")
february2025 = pd.read_csv("../data/202502-divvy-tripdata.csv")
march2025 = pd.read_csv("../data/202503-divvy-tripdata.csv")
april2025 = pd.read_csv("../data/202504-divvy-tripdata.csv")
may2025 = pd.read_csv("../data/202505-divvy-tripdata.csv")
june2025 = pd.read_csv("../data/202506-divvy-tripdata.csv")
july2025 = pd.read_csv("../data/202507-divvy-tripdata.csv")
august2025 = pd.read_csv("../data/202508-divvy-tripdata.csv")
september2025 = pd.read_csv("../data/202509-divvy-tripdata.csv")
october2025 = pd.read_csv("../data/202510-divvy-tripdata.csv")

# %%
# Combine data into groups by year - Rebecca Lazarus
divvy_data_2020 = pd.concat([april2020, may2020, june2020, july2020, august2020, september2020, october2020, novemeber2020, december2020])
divvy_data_2021 = pd.concat([january2021, february2021, march2021, april2021, may2021, june2021, july2021, august2021, september2021, october2021, novemeber2021, december2021])
divvy_data_2022 = pd.concat([january2022, february2022, march2022, april2022, may2022, june2022, july2022, august2022, september2022, october2022, novemeber2022, december2022])
divvy_data_2023 = pd.concat([january2023, february2023, march2023, april2023, may2023, june2023, july2023, august2023, september2023, october2023, novemeber2023, december2023])
divvy_data_2024 = pd.concat([january2024, february2024, march2024, april2024, may2024, june2024, july2024, august2024, september2024, october2024, novemeber2024, december2024])
divvy_data_2025 = pd.concat([january2025, february2025, march2025, april2025, may2025, june2025, july2025, august2025, september2025, october2025])

# %%
# Merge all divvy data into one large dataset - Rebecca Lazarus
divvy_data = pd.concat([divvy_data_2020, divvy_data_2021, divvy_data_2022, divvy_data_2023, divvy_data_2024, divvy_data_2025])

# %%
# Check for missing values - Rebecca Lazarus
divvy_data.isnull().sum()
# Out:
# ride_id                     0
# rideable_type               0
# started_at                  0
# ended_at                    0
# start_station_name    4649663
# start_station_id      4650418
# end_station_name      4908011
# end_station_id        4908613
# start_lat                   0
# start_lng                   0
# end_lat                 34161
# end_lng                 34161
# member_casual               0
# dtype: int64

# %%
#Impute start_station_name missing values - Rebecca Lazarus
divvy_data['lat_round'] = divvy_data['start_lat'].round(3)
divvy_data['lng_round'] = divvy_data['start_lng'].round(3)
station_name_reference = divvy_data.dropna(subset=['start_station_name'])
sation_name_lookup = dict(zip(zip(station_name_reference['lat_round'], station_name_reference['lng_round']), station_name_reference['start_station_name']))

def fill_station(row):
    if pd.notnull(row['start_station_name']):
        return row['start_station_name']
    else:
        return sation_name_lookup.get((row['lat_round'], row['lng_round']))

divvy_data['start_station_name'] = divvy_data.apply(fill_station, axis=1)

divvy_data.isnull().sum()
# Out:
# ride_id                     0
# rideable_type               0
# started_at                  0
# ended_at                    0
# start_station_name    1306480
# start_station_id      4650418
# end_station_name      4908011
# end_station_id        4908613
# start_lat                   0
# start_lng                   0
# end_lat                 34161
# end_lng                 34161
# member_casual               0
# lat_round                   0
# lng_round                   0
# dtype: int64

# %%
#Check type of remaining missing values - Rebecca Lazarus
missing_data = divvy_data[divvy_data['start_station_name'].isnull()]
print(missing_data['rideable_type'].value_counts())
# Out:
# rideable_type
# electric_bike       1290105
# electric_scooter      16369
# classic_bike              6
# Name: count, dtype: int64

# %%
#Impute remaining start_station_name values - Rebecca Lazarus
divvy_data.loc[
    (divvy_data['start_station_name'].isnull()) & (divvy_data['rideable_type'] == 'electric_bike'), 
    'start_station_name'
] = 'Public Rack'

divvy_data['start_station_name'] = divvy_data['start_station_name'].fillna('Unknown')
divvy_data.drop(columns=['lat_round', 'lng_round'], inplace = True)

divvy_data.isnull().sum()
# Out:
# ride_id                     0
# rideable_type               0
# started_at                  0
# ended_at                    0
# start_station_name          0
# start_station_id      4650418
# end_station_name      4908011
# end_station_id        4908613
# start_lat                   0
# start_lng                   0
# end_lat                 34161
# end_lng                 34161
# member_casual               0
# dtype: int64

# %%
#Impute end_station_name missing values - Rebecca Lazarus
divvy_data['lat_round'] = divvy_data['end_lat'].round(3)
divvy_data['lng_round'] = divvy_data['end_lng'].round(3)
end_station_name_reference = divvy_data.dropna(subset=['end_station_name'])
end_sation_name_lookup = dict(zip(zip(end_station_name_reference['lat_round'], end_station_name_reference['lng_round']), end_station_name_reference['end_station_name']))

def fill_end_station(row):
    if pd.notnull(row['end_station_name']):
        return row['end_station_name']
    else:
        return sation_name_lookup.get((row['lat_round'], row['lng_round']))

divvy_data['end_station_name'] = divvy_data.apply(fill_end_station, axis=1)

divvy_data.isnull().sum()
# Out:
# ride_id                     0
# rideable_type               0
# started_at                  0
# ended_at                    0
# start_station_name          0
# start_station_id      4650418
# end_station_name      1413852
# end_station_id        4908613
# start_lat                   0
# start_lng                   0
# end_lat                 34161
# end_lng                 34161
# member_casual               0
# lat_round               34161
# lng_round               34161
# dtype: int64

# %%
#Check type of remaining missing values - Rebecca Lazarus
missing_data = divvy_data[divvy_data['end_station_name'].isnull()]
print(missing_data['rideable_type'].value_counts())
# Out:
# rideable_type
# electric_bike       1361272
# classic_bike          26397
# electric_scooter      17049
# docked_bike            9134
# Name: count, dtype: int64

# %%
#Impute remaining end_station_name values - Rebecca Lazarus
divvy_data.loc[
    (divvy_data['end_station_name'].isnull()) & (divvy_data['rideable_type'] == 'electric_bike'), 
    'end_station_name'
] = 'Public Rack'

divvy_data['end_station_name'] = divvy_data['end_station_name'].fillna('Unknown')
divvy_data.drop(columns=['lat_round', 'lng_round'], inplace = True)

divvy_data.isnull().sum()
# Out:
# ride_id                     0
# rideable_type               0
# started_at                  0
# ended_at                    0
# start_station_name          0
# start_station_id      4650418
# end_station_name            0
# end_station_id        4908613
# start_lat                   0
# start_lng                   0
# end_lat                 34161
# end_lng                 34161
# member_casual               0
# dtype: int64

# %%
#Impute start_sation_id missing values - Rebecca Lazarus
start_station_id_reference = divvy_data.dropna(subset=['start_station_id'])
start_sation_id_lookup = dict(zip(start_station_id_reference['start_station_name'], start_station_id_reference['start_station_id']))

def fill_start_station_id(row):
    if pd.notnull(row['start_station_id']):
        return row['start_station_id']
    else:
        return start_sation_id_lookup.get(row['start_station_name'])

divvy_data['start_station_id'] = divvy_data.apply(fill_start_station_id, axis=1)

divvy_data.isnull().sum()
# Out:
# ride_id                     0
# rideable_type               0
# started_at                  0
# ended_at                    0
# start_station_name          0
# start_station_id      1306483
# end_station_name            0
# end_station_id        4908613
# start_lat                   0
# start_lng                   0
# end_lat                 34161
# end_lng                 34161
# member_casual               0
# dtype: int64

# %%
#Check type of remaining missing values - Rebecca Lazarus
missing_data = divvy_data[divvy_data['start_station_id'].isnull()]
print(missing_data['rideable_type'].value_counts())
# Out:
# rideable_type
# electric_bike       1290108
# electric_scooter      16369
# classic_bike              6
# Name: count, dtype: int64

# %%
#Impute remaining start_station_id values - Rebecca Lazarus
divvy_data.loc[
    (divvy_data['start_station_id'].isnull()) & (divvy_data['rideable_type'] == 'electric_bike'), 
    'start_station_id'
] = 'Public Rack'

divvy_data['start_station_id'] = divvy_data['start_station_id'].fillna('Unknown')

divvy_data.isnull().sum()
# Out:
# ride_id                     0
# rideable_type               0
# started_at                  0
# ended_at                    0
# start_station_name          0
# start_station_id            0
# end_station_name            0
# end_station_id        4908613
# start_lat                   0
# start_lng                   0
# end_lat                 34161
# end_lng                 34161
# member_casual               0
# dtype: int64

# %%
#Impute end_sation_id missing values - Rebecca Lazarus
end_station_id_reference = divvy_data.dropna(subset=['end_station_id'])
end_sation_id_lookup = dict(zip(end_station_id_reference['end_station_name'], end_station_id_reference['end_station_id']))

def fill_end_station_id(row):
    if pd.notnull(row['end_station_id']):
        return row['end_station_id']
    else:
        return end_sation_id_lookup.get(row['end_station_name'])

divvy_data['end_station_id'] = divvy_data.apply(fill_end_station_id, axis=1)

divvy_data.isnull().sum()
# Out:
# ride_id                     0
# rideable_type               0
# started_at                  0
# ended_at                    0
# start_station_name          0
# start_station_id            0
# end_station_name            0
# end_station_id        1414147
# start_lat                   0
# start_lng                   0
# end_lat                 34161
# end_lng                 34161
# member_casual               0
# dtype: int64

# %%
#Check type of remaining missing values - Rebecca Lazarus
missing_data = divvy_data[divvy_data['end_station_id'].isnull()]
print(missing_data['rideable_type'].value_counts())
# Out:
# rideable_type
# electric_bike       1361567
# classic_bike          26397
# electric_scooter      17049
# docked_bike            9134
# Name: count, dtype: int64

# %%
#Impute remaining end_station_id values - Rebecca Lazarus
divvy_data.loc[
    (divvy_data['end_station_id'].isnull()) & (divvy_data['rideable_type'] == 'electric_bike'), 
    'end_station_id'
] = 'Public Rack'

divvy_data['end_station_id'] = divvy_data['end_station_id'].fillna('Unknown')

divvy_data.isnull().sum()
# Out:
# ride_id                   0
# rideable_type             0
# started_at                0
# ended_at                  0
# start_station_name        0
# start_station_id          0
# end_station_name          0
# end_station_id            0
# start_lat                 0
# start_lng                 0
# end_lat               34161
# end_lng               34161
# member_casual             0
# dtype: int64

# %%
#Drop Missing end_lat and end_lng values (they are the same rows so we are not losing too much data) - Rebecca Lazarus
divvy_data = divvy_data.dropna(subset=['end_lat', 'end_lng'])
divvy_data.isnull().sum()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# dtype: int64

# %%
# Jonas -
# write the updated dataframe to a csv file 
# (prevents having to run through the above code again faster for development purposes)

divvy_data.to_csv('../data/imputed_divy.csv')

# %%
# Jonas - 
# read imputed data without having to rerun the above code
# (faster for development purposes)
divvy_data = pd.read_csv('../data/imputed_divy.csv', index_col=0)
# Out:
# /var/folders/8x/z6r7wqnn0dj75xm3g1lwn7gm0000gn/T/ipykernel_54416/551804291.py:4: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   divvy_data = pd.read_csv('../data/imputed_divy.csv', index_col=0)

# %%
divvy_data
# Out:
#                  ride_id  rideable_type               started_at  \
# 0       A847FADBBC638E45    docked_bike      2020-04-26 17:45:14
# 1       5405B80E996FF60D    docked_bike      2020-04-17 17:08:54
# 2       5DD24A79A4E006F4    docked_bike      2020-04-01 17:54:13
# 3       2A59BBDF5CDBA725    docked_bike      2020-04-07 12:50:19
# 4       27AD306C119C6158    docked_bike      2020-04-18 10:22:59
# ...                  ...            ...                      ...
# 646034  D13C1FED7727A9C0  electric_bike  2025-10-11 17:16:21.046
# 646035  EC76AA5F4AB2D806  electric_bike  2025-10-15 07:54:02.067
# 646036  B1FF79BE5CF46C1F  electric_bike  2025-10-25 16:44:17.353
# 646037  33AA0D781A9A7CD6  electric_bike  2025-10-08 17:10:12.295
# 646038  66E2C096F8908B13  electric_bike  2025-10-24 17:51:23.615
#
#                        ended_at                start_station_name  \
# 0           2020-04-26 18:12:03                      Eckhart Park
# ...

# %%
divvy_data
# Out:
#           Unnamed: 0           ride_id  rideable_type  \
# 0                  0  A847FADBBC638E45    docked_bike
# 1                  1  5405B80E996FF60D    docked_bike
# 2                  2  5DD24A79A4E006F4    docked_bike
# 3                  3  2A59BBDF5CDBA725    docked_bike
# 4                  4  27AD306C119C6158    docked_bike
# ...              ...               ...            ...
# 30979687      646034  D13C1FED7727A9C0  electric_bike
# 30979688      646035  EC76AA5F4AB2D806  electric_bike
# 30979689      646036  B1FF79BE5CF46C1F  electric_bike
# 30979690      646037  33AA0D781A9A7CD6  electric_bike
# 30979691      646038  66E2C096F8908B13  electric_bike
#
#                        started_at                 ended_at  \
# 0             2020-04-26 17:45:14      2020-04-26 18:12:03
# 1             2020-04-17 17:08:54      2020-04-17 17:17:03
# 2             2020-04-01 17:54:13      2020-04-01 18:08:36
# 3             2020-04-07 12:50:19      2020-04-07 13:02:31
# ...

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# Put code with comments. The comments should explain the code such that it can be easily understood. You may put text *(in a markdown cell)* before a large chunk of code to explain the overall purpose of the code, if it is not intuitive. **Put the name of the person / persons who contributed to each code chunk / set of code chunks.**

# %% [markdown]
# ### Analysis 1
# *By Jonas Goldberg*

# %%
traffic = pd.read_csv("../data/Chicago_Traffic_Tracker_-_Historical_Congestion_Estimates_by_Region_-_2018-Current.csv")

# %%
location_counts = divvy_data.groupby("start_station_name")['start_station_name'].agg('count')
location_counts = pd.DataFrame(location_counts)
location_counts = location_counts.rename(columns={'start_station_name': 'count'})
location_counts = location_counts.reset_index()
location_counts
# Out:
#                 start_station_name  count
# 0         10101 S Stony Island Ave     53
# 1     111th St - Morgan Park Metra     14
# 2              2112 W Peterson Ave   5050
# 3             21st St & Pulaski Rd    224
# 4                              351      2
# ...                            ...    ...
# 2456          Yates Blvd & 75th St   1316
# 2457          Yates Blvd & 93rd St    370
# 2458     Yates Blvd & Exchange Ave   4294
# 2459                Zapata Academy    137
# 2460              hubbard_test_lws      3
#
# [2461 rows x 2 columns]

# %%
# sample = location_counts.head(100)
plt.figure(figsize=(15, 4))
g = sns.barplot(data=location_counts, x='start_station_name', y='count')
plt.ylim(0, 400000)
plt.xlabel("Start Station")
plt.ylabel("Total Ridership Count")
#g.set_xticks(range(0, 2266, 500)) # only display select few because there are so many x labels 
# plt.xticks([])
plt.xticks(g.get_xticks()[::500], rotation=90)
plt.title("Ridership Counts at Different Stations")



plt.show()

# %% [markdown]
# There are too many stations to also plot them on the graph, so I omitted the xticks on the graph. The main idea is that ridership is influenced by the station.

# %%
# now let's see the correlation of ridership and time of year: 
divvy_data['month'] = pd.to_datetime(divvy_data['started_at'], errors='coerce')
divvy_data['month'] = divvy_data['month'].apply(lambda x: x.month)

# %%
# now let's group by month to get the counts: 
month_counts = divvy_data.groupby(['month'])['month'].agg('count')
month_counts = pd.DataFrame(month_counts)
month_counts = month_counts.rename(columns={'month': 'count'})
month_counts = month_counts.reset_index()
month_counts['month'] = month_counts['month'].apply(lambda x: int(x))
month_counts
# Out:
#     month    count
# 0       1   535174
# 1       2   578115
# 2       3  1071891
# 3       4  1633273
# 4       5  2578096
# 5       6  2558293
# 6       7  2961326
# 7       8  2980594
# 8       9  2653881
# 9      10  2113652
# 10     11  1318892
# 11     12   784370

# %%
sns.barplot(data=month_counts, x='month', y='count')
plt.xlabel("Month")
plt.ylabel("Total Counts")
plt.title("Ridership Counts By Month")
plt.show()

# %%
# traffic is congestion is either high/med/low
# this is determined based on the speed
# if speed is in bottom 33%, then there is high
# congestion (slow speed). If speed is in 66%, then it is 
# medium congestion (medium speed). Otherwise there is low 
# congestion (high speed traffic flow)

# returns .33 and .66 percentiles 
# for speed column
def percentile33(x):
    return np.quantile(x, 1/3) #1/3
def percentile66(x):
    return np.quantile(x, 2/3)

# %%
# get percentiles for each region: 
speed_per_region = traffic.groupby('REGION_ID')['SPEED'].agg([percentile33, percentile66])
speed_per_region = speed_per_region.rename(columns={"percentile33": 'low_speed', "percentile66": "medium_speed"})
speed_per_region
# Out:
#            low_speed  medium_speed
# REGION_ID
# 1              22.50         24.07
# 2              27.27         29.32
# 3              22.50         25.23
# 4              20.45         22.50
# 5              23.86         25.91
# 6              22.50         24.55
# 7              21.82         23.86
# 8              20.45         23.18
# 9              24.27         25.91
# 10             22.50         25.23
# 11             21.82         24.68
# 12             19.09         21.82
# 13             17.73         21.14
# 14             23.86         26.59
# 15             25.23         27.27
# 16             25.23         27.95
# 17             27.95         30.68
# 18             24.55         26.59
# 19             25.91         27.27
# 20             25.91         27.27
# 21             23.86         26.59
# 22             28.64         30.68
# 23             23.18         25.23
# 24             25.23         27.27
# 25             28.64         30.68
# ...

# %%
# we will determine if a bike route is in a traffic station 
# based on the start location of the bike. 
# To determine if a bike station is in a traffic region: 
# WEST <= start_lng <= EAST and
# SOUTH <= start_lat <= NORTH

# first let's get unique regions 
duplicates = traffic['REGION_ID'].duplicated()
duplicates = ~duplicates
regions = traffic[duplicates]

# %%
# OPTIMIZED REGION FINDER: 
bools = []

for i in range(29): # 29 if going up
    west = regions.iloc[i].loc['WEST']
    east = regions.iloc[i].loc['EAST']
    south = regions.iloc[i].loc['SOUTH']
    north = regions.iloc[i].loc['NORTH']
    lng_indices = (west <= divvy_data['start_lng']) & (divvy_data['start_lng'] <= east)
    lat_indices = (south <= divvy_data['start_lat']) & (divvy_data['start_lat'] <= north)
    indices = lng_indices & lat_indices
    bools.append(indices)

# multiple = np.array(bools)
final_index = pd.Series(np.array([-1] * len(bools[0])))

# final_index = bools[0]


for id, index in enumerate(bools):
    indices = final_index < 0
    final_index[index.to_numpy() & indices.to_numpy()] = id + 1

indices = final_index < 0
final_index[indices] = pd.NA

# %%
divvy_data['region_id'] = final_index

# Filter NANs
nulls = divvy_data['region_id'].isnull()
divvy_data = divvy_data[~nulls]

# next, we need to find the traffic congestion time that is 
# closest to ridership 'started_at' time. This is to get 
# the traffic congestion measurement and then extract the 
# speed (to determine if there is high/low congestion)

# %%
divvy_data['started_at'] = pd.to_datetime(divvy_data['started_at'], errors='coerce')
traffic['TIME'] = pd.to_datetime(traffic['TIME'])

# filter null dates
null_dates = divvy_data['started_at'].isnull()
divvy_data = divvy_data[~null_dates]
# Out:
# C:\Users\Jonas\AppData\Local\Temp\ipykernel_24560\1343207523.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   divvy_data['started_at'] = pd.to_datetime(divvy_data['started_at'], errors='coerce')
# C:\Users\Jonas\AppData\Local\Temp\ipykernel_24560\1343207523.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   traffic['TIME'] = pd.to_datetime(traffic['TIME'])

# %%
# sort the dates. Sorting will allow us to efficiently execute an algorithim that will be explained later
divvy_data = divvy_data.sort_values("started_at").reset_index(drop=True)
traffic = traffic.sort_values("TIME").reset_index(drop=True)

# %%
# we need to find the traffic time stamp that is closest to each divvy time stamp. 
# This is because we want to get the traffic estimate at the closest time to when
# someone begins their bike ride. 

# Due to the sheer number of rows in both datasets, iterating through each one and finding the minimum 
# is too costly. As a result, sorting the time stamps makes it more efficient because the closest 
# time stamp will be equal to or greater than the index of the previous closest time stamp. 

# NAIVE METHOD (takes too long)
# mins = []
# traffic_times = traffic['TIME'].values
# divvy_times = divvy_data['started_at'].values

# for i in range(divvy_data.shape[0]):
#     diff = np.abs(traffic_times - divvy_times[i])
#     mins.append(diff.argmin())


# OPTIMAL APPROACH: 
def find_min(traffic_times, divvy_point, curr_min):
    min_diff = abs(traffic_times[curr_min] - divvy_point)
    for i in range(curr_min, traffic_times.shape[0]):
        curr_diff = abs(traffic_times[i] - divvy_point)
        if curr_diff < min_diff:
            min_diff = curr_diff
            curr_min = i
        if curr_diff > min_diff:
            return curr_min
    return curr_min

divvy_times = divvy_data['started_at'].astype(int).to_numpy()
traffic_times = traffic['TIME'].astype(int).to_numpy()

# first find the current minimum naively: 
curr_min = np.abs(divvy_times[0] - traffic_times).argmin()
mins = [curr_min]

# %%
for i in range(1, divvy_times.shape[0]):
    curr_min = find_min(traffic_times, divvy_times[i], curr_min)
    mins.append(curr_min)


mins = np.asarray(mins)
divvy_data['speed'] = traffic['SPEED'][mins].reset_index()['SPEED']

# %%
# finally, we determine based on the speed if there is 
# low/medium/high congestion
def congestion_rate(row):
    id = row['region_id']
    if row['speed'] <= speed_per_region.loc[id, 'low_speed']:
        return 'high'
    if row['speed'] <= speed_per_region.loc[id, 'medium_speed']:
        return 'medium'
    return 'low'

congestion_vals = divvy_data.apply(congestion_rate, axis=1)
divvy_data['congestion'] = congestion_vals

# %%
sns.countplot(data=divvy_data, x='congestion')
plt.title("Congestsion Counts for Ridership")
plt.show()

# %% [markdown]
# ### Analysis 2
# *By Rebecca Lazarus*

# %%
CTA = pd.read_csv("../data/CTA_Ridership_Totals.csv")

# %%
#Setting up consistent style for graphs
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
sns.set_theme(style="whitegrid")
colors = {
    'CTA': '#003366',  # Deep professional blue
    'Divvy': '#E31A1C' # Bright energetic orange
}
plt.rcParams.update({
    'font.size': 12,
    'axes.titlesize': 16,
    'axes.labelsize': 14,
    'xtick.labelsize': 11,
    'ytick.labelsize': 11,
    'legend.fontsize': 12,
    'legend.title_fontsize': 13
})
def clean_spines(ax):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

# %%
#DIVVY DATA
#convert start date for graphing
divvy_data['started_at'] = pd.to_datetime(divvy_data['started_at'], format = 'mixed')
divvy_data['month_year'] = divvy_data['started_at'].dt.to_period('M')
counts = divvy_data.groupby('month_year').size().reset_index(name='count')
counts['month_year'] = counts['month_year'].dt.to_timestamp()

#CTA DATA
#prep for graph
CTA['total_rides'] = pd.to_numeric(CTA['total_rides'].astype(str).str.replace(',', ''), errors='coerce')
CTA['bus'] = pd.to_numeric(CTA['bus'].astype(str).str.replace(',', ''), errors='coerce')
CTA['rail_boardings'] = pd.to_numeric(CTA['rail_boardings'].astype(str).str.replace(',', ''), errors='coerce')
CTA['service_date'] = pd.to_datetime(CTA['service_date'])
CTA['year'] = CTA['service_date'].dt.year
CTA['month_year'] = CTA['service_date'].dt.to_period('M')
CTA['month_year'] = CTA['month_year'].dt.to_timestamp()
CTA_2020_on = CTA[(CTA['month_year'] >= pd.Timestamp('2020-04-01')) & (CTA['month_year'] <= pd.Timestamp('2025-10-01'))]
CTA_monthly = CTA_2020_on.groupby('month_year', as_index=False)['total_rides'].sum()

# %%
fig, ax = plt.subplots(figsize=(14, 7))

# Plot CTA
sns.lineplot(
    data=CTA_monthly, 
    x='month_year', 
    y='total_rides', 
    color=colors['CTA'], 
    marker='s', 
    label='CTA Rides',
    linewidth=3,
    ax=ax
)

# Plot Divvy
sns.lineplot(
    data=counts, 
    x='month_year', 
    y='count', 
    color=colors['Divvy'], 
    marker='o', 
    label='Divvy Rides',
    linewidth=3,
    ax=ax
)

ax.set_yscale('log')
plt.title('Comparison of Scale: CTA vs. Divvy (Log Scale)', fontsize=16, pad=20)
plt.ylabel('Monthly Rides (Log Scale)', fontweight='bold')
plt.xlabel('Date', fontweight='bold')
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:,.0f}'.format(y)))

ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=45)

clean_spines(ax)
plt.legend(bbox_to_anchor = (1,1))
plt.tight_layout();

# %%
#Look closer at just Divvy
plt.figure(figsize=(18, 6))
ax = sns.lineplot(data=counts, x = 'month_year', y = 'count', marker = 'o', color=colors['Divvy'], markersize=8, linewidth=3)
plt.title('Deep Dive: Total Divvy Rides Over Time', pad=20)
plt.ylabel('Monthly Rides', fontweight='bold')
plt.xlabel('Date', fontweight='bold')
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=45)
clean_spines(ax)
plt.tight_layout();

# %%
#Day of the week Analysis
CTA_2020_on['day_name'] = CTA_2020_on['service_date'].dt.day_name()
CTA_grouped = CTA_2020_on.groupby('day_name')['total_rides'].sum().reset_index()
CTA_grouped['Proportion'] = CTA_grouped['total_rides'] / CTA_grouped['total_rides'].sum()
CTA_grouped['Dataset'] = 'CTA'
CTA_Day_data = CTA_grouped[['day_name', 'Proportion', 'Dataset']]

divvy_data['day_name'] = divvy_data['started_at'].dt.day_name()
divvy_counts = divvy_data.groupby('day_name').size().reset_index(name='count')
divvy_Day_data = divvy_counts[['day_name', 'count']].copy()
divvy_Day_data.columns = ['day_name', 'Rides']
divvy_Day_data['Proportion'] = divvy_Day_data['Rides'] / divvy_Day_data['Rides'].sum()
divvy_Day_data['Dataset'] = 'Divvy'
divvy_Day_data = divvy_Day_data[['day_name', 'Proportion', 'Dataset']]
combined_data = pd.concat([CTA_Day_data, divvy_Day_data])
# Out:
# /var/folders/02/vhd5ybdx0vj7z1jf7ckg0zv40000gn/T/ipykernel_21913/1101958674.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CTA_2020_on['day_name'] = CTA_2020_on['service_date'].dt.day_name()

# %%
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

ax = sns.barplot(
    data=combined_data, 
    x='day_name', 
    y='Proportion', 
    hue='Dataset', 
    order=days_order,
    palette=colors
)
plt.title('Comparison of CTA vs Divvy Rides by Day', pad=20)
plt.ylabel('Proportion of Weekly Total', fontweight='bold')
plt.xlabel('Day of the Week', fontweight='bold')
plt.xticks(rotation=45)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
plt.legend(title='Dataset', title_fontsize='13', bbox_to_anchor = (1,1))
clean_spines(ax)
plt.tight_layout();

# %% [markdown]
# ### Analysis 3
# *By \Victoria*

# %%
from glob import glob
files=sorted(glob("../data/*.csv"))
chi=gpd.read_file("../chicago-community-areas.geojson")
biz=pd.read_csv("../victoriadata/Business_Licenses_-_Current_Active_20251201.csv")
mmrp=pd.read_csv("../victoriadata/Micro-Market_Recovery_Program_-_Permits_20251201.csv")
# Out:
# /var/folders/dv/4lbmvmw16wj_zrkwhb7ng9bm0000gn/T/ipykernel_2376/3691574573.py:4: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   biz=pd.read_csv("../victoriadata/Business_Licenses_-_Current_Active_20251201.csv")
# /var/folders/dv/4lbmvmw16wj_zrkwhb7ng9bm0000gn/T/ipykernel_2376/3691574573.py:5: DtypeWarning: Columns (2,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   mmrp=pd.read_csv("../victoriadata/Micro-Market_Recovery_Program_-_Permits_20251201.csv")

# %%
dfs = []
for f in files:
    temp = pd.read_csv(f, low_memory=False)
    dfs.append(temp)
divvy= pd.concat(dfs, ignore_index=True)

#fill in missing station names based on IDs- Victoria's way
station_reference= (divvy[['start_station_id', 'start_station_name']].dropna().drop_duplicates())
divvy= divvy.merge(station_reference,on='start_station_id',how='left',suffixes=("", "_ref"))
divvy['start_station_name'] = divvy['start_station_name'].fillna(divvy['start_station_name_ref'])
divvy= divvy.drop(columns=['start_station_name_ref'])

df_loc= divvy.dropna(subset=['start_lat', 'start_lng'])
#sample to keep numbers manageable
if len(df_loc) > 200_000:
    df_loc= df_loc.sample(200_000, random_state=0)

len(df_loc)
# Out:
# 200000

# %%
# Datetime + year
divvy['started_at'] = divvy['started_at'].astype(str).str.strip()
divvy['started_at'] = pd.to_datetime(
    divvy['started_at'],
    errors='coerce',
    format='mixed'
)
divvy = divvy.dropna(subset=['started_at'])
divvy['year'] = divvy['started_at'].dt.year

# Only docked trips
docked = divvy.dropna(subset=['start_station_id'])

# First year each station appears
station_first_year = (
    docked
    .groupby('start_station_id')['year']
    .min()
    .reset_index()
    .rename(columns={'year': 'year_opened'})
)

# Station table with coords
stations_meta = (
    docked[['start_station_id', 'start_station_name', 'start_lat', 'start_lng']]
    .drop_duplicates(subset='start_station_id')
    .rename(columns={
        'start_station_id': 'station_id',
        'start_station_name': 'station_name',
        'start_lat': 'lat',
        'start_lng': 'lng'
    })
)

stations = stations_meta.merge(
    station_first_year.rename(columns={'start_station_id': 'station_id'}),
    on='station_id',
    how='left'
)

# %%
#year
divvy['started_at']= divvy['started_at'].astype(str).str.strip()
divvy['started_at']= pd.to_datetime(divvy['started_at'],errors='coerce',format='mixed')
divvy['year']= divvy['started_at'].dt.year

docked= divvy.dropna(subset=['start_station_id'])
docked.head()
# Out:
#             ride_id rideable_type          started_at             ended_at  \
# 0  A847FADBBC638E45   docked_bike 2020-04-26 17:45:14  2020-04-26 18:12:03
# 1  5405B80E996FF60D   docked_bike 2020-04-17 17:08:54  2020-04-17 17:17:03
# 2  5405B80E996FF60D   docked_bike 2020-04-17 17:08:54  2020-04-17 17:17:03
# 3  5DD24A79A4E006F4   docked_bike 2020-04-01 17:54:13  2020-04-01 18:08:36
# 4  2A59BBDF5CDBA725   docked_bike 2020-04-07 12:50:19  2020-04-07 13:02:31
#
#              start_station_name start_station_id             end_station_name  \
# 0                  Eckhart Park               86  Lincoln Ave & Diversey Pkwy
# 1     Drake Ave & Fullerton Ave              503              Kosciuszko Park
# 2     Drake Ave & Fullerton Ave              503              Kosciuszko Park
# 3          McClurg Ct & Erie St              142   Indiana Ave & Roosevelt Rd
# 4  California Ave & Division St              216       Wood St & Augusta Blvd
#
# ...

# %%
#use 2025 stations to find when stations were built
stations_2025_ids= (docked.loc[docked['year'] == 2025, 'start_station_id'].unique())
docked_2025_universe = docked[
    docked['start_station_id'].isin(stations_2025_ids)]
stations = (docked_2025_universe.groupby('start_station_id')
    .agg(year_opened=('year', 'min'),station_name=('start_station_name', 'first'),lat=('start_lat', 'first'),lng=('start_lng', 'first'))
    .reset_index().rename(columns={'start_station_id': 'station_id'}))

stations['year_opened'].value_counts().sort_index()
# Out:
# year_opened
# 2020     636
# 2021     111
# 2022     327
# 2023     251
# 2024     215
# 2025    1769
# Name: count, dtype: int64

# %%
years = np.arange(2020, 2026)
minx, miny, maxx, maxy = chi.total_bounds

fig, axes=plt.subplots(2, 3, figsize=(12, 10), sharex=True, sharey=True)
axes_flat= axes.ravel()

for i, year in enumerate(years):
    ax=axes_flat[i]
    subset=stations[stations['year_opened'] == year]
    bw=0.2
    if year == 2022:
        bw=0.1
    sns.kdeplot(data=subset,x='lng',y='lat',fill=True,
        bw_adjust=bw,cmap='YlGnBu',ax=ax)

    chi.plot(ax=ax, edgecolor='black', facecolor='none', linewidth=1)

    if year == 2020:
        ax.set_title("Docks in 2020")
    else:
        ax.set_title(f"New docks built in {year}")

    ax.set_xlim(minx, maxx)
    ax.set_ylim(miny, maxy)
    ax.set_xlabel("")
    ax.set_ylabel("")
plt.show()

# %%
#also find long and lat
biz = biz.dropna(subset=['LATITUDE', 'LONGITUDE'])
biz_gdf= gpd.GeoDataFrame(biz,geometry=gpd.points_from_xy(biz['LONGITUDE'], biz['LATITUDE']),crs="EPSG:4326")

mmrp= mmrp.dropna(subset=['Latitude', 'Longitude'])
mmrp_gdf=gpd.GeoDataFrame(mmrp,geometry=gpd.points_from_xy(mmrp['Longitude'], mmrp['Latitude']),crs="EPSG:4326")


fig, ax=plt.subplots(figsize=(7, 9))
chi.plot(ax=ax, edgecolor='black', facecolor='none', linewidth=1)

biz_gdf.plot(ax=ax, markersize=1, color='tab:blue', alpha=0.3, label="Business license")
mmrp_gdf.plot(ax=ax, markersize=1, color='tab:orange', alpha=0.3, label="MMRP permit")

ax.set_title("Business licenses & MMRP permits over Chicago community areas")
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_aspect('equal', 'box')
ax.legend()

plt.show()

# %%
stations_gdf= gpd.GeoDataFrame(stations,geometry=gpd.points_from_xy(stations['lng'], stations['lat']),crs="EPSG:4326")
stations_in_comm= gpd.sjoin(stations_gdf.to_crs(chi.crs),chi,how='inner',predicate='within')
station_counts= (stations_in_comm.groupby('community').size().reset_index(name='station_count'))

biz_joined= gpd.sjoin(biz_gdf,chi,how='inner',predicate='within')
business_counts= (biz_joined.groupby('community').size().reset_index(name='business_count'))

mmrp_joined= gpd.sjoin(mmrp_gdf,chi,how='inner',predicate='within')
mmrp_counts= (mmrp_joined.groupby('community').size().reset_index(name='mmrp_count'))

print(business_counts['business_count'].sum())
print(mmrp_counts['mmrp_count'].sum())
# Out:
# 49078
# 42879

# %%
community_stats= (station_counts.merge(business_counts, on='community', how='left').merge(mmrp_counts, on='community', how='left'))
community_stats[['business_count', 'mmrp_count']] = (community_stats[['business_count', 'mmrp_count']].fillna(0))

community_stats.head()
# Out:
#         community  station_count  business_count  mmrp_count
# 0     ALBANY PARK             56             821         0.0
# 1  ARCHER HEIGHTS             29             331         0.0
# 2   ARMOUR SQUARE             26             435         0.0
# 3         ASHBURN             66             391         0.0
# 4  AUBURN GRESHAM             62             401      3626.0

# %%
comm_with_counts = chi.merge(station_counts, on='community', how='left')
comm_with_counts['station_count'] = comm_with_counts['station_count'].fillna(0)

ax = comm_with_counts.plot(column='station_count',cmap='YlGnBu',legend=True,edgecolor='black',linewidth=0.5,figsize=(7, 9))
ax.set_title("Number of Divvy stations per Chicago community")
plt.show()

# %%
community_stats['econ_total'] = (community_stats['business_count'] + community_stats['mmrp_count'])
community_stats['bike_need_index'] = (community_stats['econ_total'] / (community_stats['station_count'] + 1))

potential_map = chi.merge(community_stats[['community', 'station_count', 'econ_total', 'bike_need_index']],on='community',how='left')


fig, ax = plt.subplots(figsize=(8, 10))

potential_map.plot(column='bike_need_index',cmap='Reds',legend=True,edgecolor='black',linewidth=0.5,ax=ax)
ax.set_title("Business & MMRP activity per Divvy station\n(higher = greater need for more docks)")
ax.set_axis_off()
plt.show()

top_potential = (community_stats.sort_values('bike_need_index', ascending=False).head(10)[['community', 'station_count', 'business_count', 'mmrp_count', 'bike_need_index']])
print(top_potential.to_string(index=False))
# Out:
#       community  station_count  business_count  mmrp_count  bike_need_index
#       ENGLEWOOD             53             196      7334.0       139.444444
# GRAND BOULEVARD             44             284      4108.0        97.600000
#        WOODLAWN             58             230      5427.0        95.881356
#           OHARE              7             564         0.0        70.500000
#  BELMONT CRAGIN             90            1110      5184.0        69.164835
#    WEST PULLMAN             39             163      2444.0        65.175000
#  AUBURN GRESHAM             62             401      3626.0        63.920635
#         CHATHAM             59             421      3000.0        57.016667
#   HUMBOLDT PARK             67             759      3074.0        56.367647
#         PULLMAN             28              97      1532.0        56.172414

# %% [markdown]
# ### Analysis 4
# *By Brandon Wolmer*

# %%
# Reading the 2020 Census Data sepereated by Zip code in CHhcago Containing Data on Age, Sex, Race, and Income. - By Brandon Wolmer

age_data = pd.read_excel("../Census_Data/2020_Age_data.xlsx", header=0)
race_data = pd.read_excel("../Census_Data/2020_Race_by_Zip.xlsx", header=0)
income_data = pd.read_excel("../Census_Data/2020_Household_Income.xlsx", header=0)

# %%
# Dropping Rows from the data sets that will not be used in the Analysis - By Brandon Wolmer

age_data_clean = age_data.drop(age_data.index[0:4])
age_data_clean = age_data_clean.drop(age_data.index[22:])


race_data_clean = race_data.drop(race_data.index[2:4])
race_data_clean = race_data_clean.drop(race_data.index[11:])

income_data_clean = income_data.drop(income_data.index[0:3])
income_data_clean = income_data_clean.drop(income_data.index[15:])
race_data_clean.head()


# seting the label column as the index
race_data_clean = race_data_clean.set_index('Label')
age_data_clean = age_data_clean.set_index('Unnamed: 0')
income_data_clean = income_data_clean.set_index('Unnamed: 0')

# %%
#Converting values in Dataframes to numeric - By Brandon Wolmer

age_data_clean = age_data_clean.replace({',':'', '%':''}, regex=True)
age_data_clean = age_data_clean.apply(pd.to_numeric, errors='coerce')

race_data_clean = race_data_clean.replace({',':'', '%':''}, regex=True)
race_data_clean = race_data_clean.apply(pd.to_numeric, errors='coerce')

income_data_clean = income_data_clean.replace({',':'', '%':''}, regex=True)
income_data_clean = income_data_clean.apply(pd.to_numeric, errors='coerce')

# %%
#expressing Race as Percentages - By Brandon Wolmer

totals = race_data_clean.iloc[0]
race_data_clean = race_data_clean / totals
race_data_clean = race_data_clean * 100

race_data_clean = race_data_clean.drop('Total:')
# Out:
#                                          ZCTA5 60601  ZCTA5 60602  \
# Label
# Hispanic or Latino                          7.581889     9.119746
# White alone                                59.504237    56.463125
# Black or African American alone             5.008221     5.709754
# American Indian and Alaska Native alone     0.120147     0.158604
# Asian alone                                22.682433    22.283902
#
#                                          ZCTA5 60603  ZCTA5 60604  \
# Label
# Hispanic or Latino                          7.065217     6.688963
# White alone                                57.298137    58.751394
# Black or African American alone             4.192547     8.695652
# American Indian and Alaska Native alone     0.000000     0.111483
# Asian alone                                25.698758    19.955407
#
#                                          ZCTA5 60605  ZCTA5 60606  \
# Label
# Hispanic or Latino                          7.933433     6.847511
# ...

# %%
# Reshaping Data to prep for future merge - By Brandon Wolmer

age_data_clean_T = age_data_clean.T
race_data_clean_T = race_data_clean.T
income_data_clean_T = income_data_clean.T

# %%
#Merging the three datasets into one dataframe - By Brandon Wolmer
census_data = pd.concat([age_data_clean_T, race_data_clean_T, income_data_clean_T], axis=1)

# %%
#checking for missing values - By Brandon Wolmer

missing = census_data.isnull().sum()
print(missing.iloc[:20])
# Out:
# Under 5 years         0
# 5 to 9 years          0
# 10 to 14 years        0
# 15 to 19 years        0
# 20 to 24 years        0
# 25 to 29 years        0
# 30 to 34 years        0
# 35 to 39 years        0
# 40 to 44 years        0
# 45 to 49 years        0
# 50 to 54 years        0
# 55 to 59 years        0
# 60 to 64 years        0
# 65 to 69 years        0
# 70 to 74 years        0
# 75 to 79 years        0
# 80 to 84 years        0
# 85 years and over     0
# Total:                0
# Hispanic or Latino    0
# dtype: int64

# %%
#checking for missing value part 2 - By Brandon Wolmer
print(missing.iloc[20:37])
# Out:
# White alone                                         0
# Black or African American alone                     0
# American Indian and Alaska Native alone             0
# Asian alone                                         0
# Native Hawaiian and Other Pacific Islander alone    0
# Some Other Race alone                               0
# Population of two or more races:                    0
# Less than $10,000                                   0
# $10,000 to $14,999                                  0
# $15,000 to $24,999                                  0
# $25,000 to $34,999                                  0
# $35,000 to $49,999                                  0
# $50,000 to $74,999                                  0
# $75,000 to $99,999                                  0
# $100,000 to $149,999                                0
# $150,000 to $199,999                                0
# $200,000 or more                                    0
# dtype: int64

# %%
# Selecting Divvy Data from just the year 2020 - By Brandon Wolmer
divvy_data['started_at'] = pd.to_datetime(divvy_data['started_at'], errors='coerce')
divvy_2020 = divvy_data[divvy_data['started_at'].dt.year == 2020].copy()
divvy_2020.head()
# Out:
#             ride_id rideable_type          started_at             ended_at  \
# 0  A847FADBBC638E45   docked_bike 2020-04-26 17:45:14  2020-04-26 18:12:03
# 1  5405B80E996FF60D   docked_bike 2020-04-17 17:08:54  2020-04-17 17:17:03
# 2  5DD24A79A4E006F4   docked_bike 2020-04-01 17:54:13  2020-04-01 18:08:36
# 3  2A59BBDF5CDBA725   docked_bike 2020-04-07 12:50:19  2020-04-07 13:02:31
# 4  27AD306C119C6158   docked_bike 2020-04-18 10:22:59  2020-04-18 11:15:54
#
#              start_station_name start_station_id             end_station_name  \
# 0                  Eckhart Park               86  Lincoln Ave & Diversey Pkwy
# 1     Drake Ave & Fullerton Ave              503              Kosciuszko Park
# 2          McClurg Ct & Erie St              142   Indiana Ave & Roosevelt Rd
# 3  California Ave & Division St              216       Wood St & Augusta Blvd
# 4          Rush St & Hubbard St              125   Sheridan Rd & Lawrence Ave
#
# ...

# %%
#findind the latitude and longitude of every Zip code in the census data that we use - By Brandon Wolmer
lat_long_data = pd.read_excel("../Census_Data/long_lat_zip.xlsx", header=0)


lat_long_data['zip'] = 'ZCTA5 ' + lat_long_data['zip'].astype(str)
lat_long_data = lat_long_data[lat_long_data['zip'].isin(census_data.index)].reset_index(drop=True)
lat_long_data = lat_long_data.loc[:, ['zip', 'lat', 'lng']]
lat_long_data.head()
# Out:
#            zip       lat       lng
# 0  ZCTA5 60601  41.88527 -87.62197
# 1  ZCTA5 60602  41.88304 -87.62906
# 2  ZCTA5 60603  41.88018 -87.62740
# 3  ZCTA5 60604  41.87799 -87.62928
# 4  ZCTA5 60605  41.86644 -87.61956

# %%
#finding the closest census zip code for each start lat and long in the 2020 divvy data (I will be using euclidean distance for this) - By Brandon Wolmer

divvy_lats = divvy_2020['start_lat'].to_numpy().astype(float)
divvy_longs = divvy_2020['start_lng'].to_numpy().astype(float)

zip_lats = lat_long_data['lat'].to_numpy().astype(float)
zip_longs = lat_long_data['lng'].to_numpy().astype(float)

divvy_lats  = divvy_lats.reshape(-1, 1)
divvy_longs = divvy_longs.reshape(-1, 1)

zip_lats = zip_lats.reshape(1, -1)
zip_longs = zip_longs.reshape(1, -1)

dist_sq = (divvy_lats - zip_lats)**2 + (divvy_longs - zip_longs)**2
nearest_idx = dist_sq.argmin(axis=1)

zip_codes = lat_long_data['zip'].to_numpy()
divvy_2020['start_zip'] = zip_codes[nearest_idx]

divvy_2020.head()
# Out:
#             ride_id rideable_type          started_at             ended_at  \
# 0  A847FADBBC638E45   docked_bike 2020-04-26 17:45:14  2020-04-26 18:12:03
# 1  5405B80E996FF60D   docked_bike 2020-04-17 17:08:54  2020-04-17 17:17:03
# 2  5DD24A79A4E006F4   docked_bike 2020-04-01 17:54:13  2020-04-01 18:08:36
# 3  2A59BBDF5CDBA725   docked_bike 2020-04-07 12:50:19  2020-04-07 13:02:31
# 4  27AD306C119C6158   docked_bike 2020-04-18 10:22:59  2020-04-18 11:15:54
#
#              start_station_name start_station_id             end_station_name  \
# 0                  Eckhart Park               86  Lincoln Ave & Diversey Pkwy
# 1     Drake Ave & Fullerton Ave              503              Kosciuszko Park
# 2          McClurg Ct & Erie St              142   Indiana Ave & Roosevelt Rd
# 3  California Ave & Division St              216       Wood St & Augusta Blvd
# 4          Rush St & Hubbard St              125   Sheridan Rd & Lawrence Ave
#
# ...

# %%
#Counting How many rides started in each ZCTA - By Brandon Wolmer
zip_counts = divvy_2020.groupby('start_zip').size().reset_index(name='ride_count')
zip_counts = zip_counts.set_index('start_zip')
zip_counts.head()

census_data['divvy_ride_count'] = zip_counts['ride_count']

# %%
#combining age ranges into generational categories - By Brandon Wolmer

gen_alpha = ['Under 5 years', '5 to 9 years']
gen_z = ['10 to 14 years', '15 to 19 years', '20 to 24 years']
mellennials = ['25 to 29 years', '30 to 34 years', '35 to 39 years']
gen_x = ['40 to 44 years', '45 to 49 years', '50 to 54 years']
boomers = ['55 to 59 years', '60 to 64 years', '65 to 69 years', '70 to 74 years']
silent_gen = ['75 to 79 years', '80 to 84 years', '85 years and over']

census_data['Gen Alpha'] = census_data[gen_alpha].sum(axis=1)
census_data['Gen Z'] = census_data[gen_z].sum(axis=1)
census_data['Millennials'] = census_data[mellennials].sum(axis=1)
census_data['Gen X'] = census_data[gen_x].sum(axis=1)
census_data['Baby Boomers'] = census_data[boomers].sum(axis=1)
census_data['Silent Generation'] = census_data[silent_gen].sum(axis=1)

#Combining Income Ranges into tax brackets

very_low_cols = ['Less than $10,000', '$10,000 to $14,999', '$15,000 to $24,999']

low_cols = ['$25,000 to $34,999', '$35,000 to $49,999']

lower_middle_cols = ['$50,000 to $74,999']

middle_cols = ['$75,000 to $99,999']

upper_middle_cols = ['$100,000 to $149,999']

high_cols = ['$150,000 to $199,999', '$200,000 or more']

census_data['Very Low Income'] = census_data[very_low_cols].sum(axis=1)
census_data['Low Income'] = census_data[low_cols].sum(axis=1)
census_data['Lower Middle'] = census_data[lower_middle_cols].sum(axis=1)
census_data['Middle Income'] = census_data[middle_cols].sum(axis=1)
census_data['Upper Middle'] = census_data[upper_middle_cols].sum(axis=1)
census_data['High Income'] = census_data[high_cols].sum(axis=1)

census_data.head()
# Out:
#              Under 5 years  5 to 9 years  10 to 14 years  15 to 19 years  \
# ZCTA5 60601            1.9           2.3             0.8             5.1
# ZCTA5 60602            3.1           2.1             2.1             0.8
# ZCTA5 60603            0.3           0.3             0.0            13.2
# ZCTA5 60604            0.0           0.0             0.0            10.6
# ZCTA5 60605            4.4           2.3             1.4             4.8
#
#              20 to 24 years  25 to 29 years  30 to 34 years  35 to 39 years  \
# ZCTA5 60601             8.1            19.8            12.9             8.1
# ZCTA5 60602             4.6            15.4            26.1            27.8
# ZCTA5 60603            11.8            11.4            20.1             0.8
# ZCTA5 60604            21.9            11.1            20.7             2.7
# ZCTA5 60605             7.9            15.7            16.4            11.0
#
# ...

# %%
#saving the clean census data to a csv file - By Brandon Wolmer
census_data.to_csv("../Census_Data/census_data.csv")

# %%
# - By Brandon Wolmer
census_data = pd.read_csv("../Census_Data/census_data.csv", index_col=0)

# %%
# Correlation Barplot between Divvy Ride Counts and Census Data Features - By Brandon Wolmer

corr = census_data.corr()['divvy_ride_count'].drop('divvy_ride_count')
corr_sorted = corr.sort_values(ascending=False)

age_cols = ['Gen Alpha', 'Gen Z', 'Millennials', 'Gen X', 'Baby Boomers', 'Silent Generation']
corr_age = corr_sorted.loc[age_cols]

race_cols = ['Hispanic or Latino', 'White alone', 'Black or African American alone',   'American Indian and Alaska Native alone', 'Asian alone', 'Native Hawaiian and Other Pacific Islander alone', 'Some Other Race alone', 'Population of two or more races:']
corr_race = corr_sorted.loc[race_cols]

income_cols = ['Very Low Income', 'Low Income', 'Lower Middle', 'Middle Income', 'Upper Middle', 'High Income']
corr_income = corr_sorted.loc[income_cols]

fig, axes = plt.subplots(1, 3, figsize=(18, 10))
sns.barplot(x=corr_age.values, y=corr_age.index, ax=axes [0], color='orange')
axes[0].set_xlabel('Correlation', fontsize=12)
axes[0].set_ylabel('Age Group', fontsize=12)
axes[0].set_title('Correlation with Age Features', fontsize=14)


sns.barplot(x=corr_race.values, y=corr_race.index, ax=axes [1])
axes[1].set_xlabel('Correlation', fontsize=12)
axes[1].set_ylabel('Race Group', fontsize=12)
axes[1].set_title('Correlation with Race Features', fontsize=14)


sns.barplot(x=corr_income.values, y=corr_income.index, ax=axes [2], color = 'green')
axes[2].set_xlabel('Correlation', fontsize=12)
axes[2].set_ylabel('Income Bracket', fontsize=12)
axes[2].set_title('Correlation with Income Features', fontsize=14)

plt.suptitle('Correlation between Divvy Ride Counts and Census Data Features', fontsize=16)
plt.tight_layout()

# %%
# Barplot of Divvy Ride Counts by Tax Bracket - By Brandon Wolmer

bins = [0, 25000, 45000, 65000, 85000, 115000, np.inf]
labels = ['Very Low Income (<25k)', 'Low Income (25 to 45k)', 'Lower Middle (45 to 65k)', 'Middle Income (65 to 85k)', 'Upper Middle (85 to 115k)', 'High Income (above 115k)']
census_data['tax bracket'] = pd.cut(census_data['Median income (dollars)'], bins=bins, labels=labels)

figure = plt.figure(figsize=(18, 10))
sns.barplot(data=census_data, x='tax bracket', y = 'divvy_ride_count', estimator=np.sum, errorbar=None)
plt.xlabel('Tax Bracket', fontsize=14)
plt.ylabel('Divvy Ride Count', fontsize=14)
plt.title('Divvy Ride Counts by Tax Bracket', fontsize=18)
plt.tight_layout()

# %%
#Loading Census Tract shapefile for Chicago - By Brandon Wolmer

chi = gpd.read_file(r"../Census_Data/CensusTracts2010/CensusTractsTIGER2010.shp")
chi = chi.to_crs('EPSG:4326')

# %%
#mapping the majority age, race, and income level of the zip code each ride originated in to the divvy 2020 data - By Brandon Wolmer

divvy_2020['tax bracket'] = divvy_2020['start_zip'].map(census_data['tax bracket'])

census_data['majority_race'] = census_data[race_cols].idxmax(axis=1)
census_data['age_group'] = census_data[age_cols].idxmax(axis=1)

divvy_2020['majority_race'] = divvy_2020['start_zip'].map(census_data['majority_race'])
divvy_2020['Majority_age_group'] = divvy_2020['start_zip'].map(census_data['age_group'])

divvy_2020.head()
# Out:
#             ride_id rideable_type          started_at             ended_at  \
# 0  A847FADBBC638E45   docked_bike 2020-04-26 17:45:14  2020-04-26 18:12:03
# 1  5405B80E996FF60D   docked_bike 2020-04-17 17:08:54  2020-04-17 17:17:03
# 2  5DD24A79A4E006F4   docked_bike 2020-04-01 17:54:13  2020-04-01 18:08:36
# 3  2A59BBDF5CDBA725   docked_bike 2020-04-07 12:50:19  2020-04-07 13:02:31
# 4  27AD306C119C6158   docked_bike 2020-04-18 10:22:59  2020-04-18 11:15:54
#
#              start_station_name start_station_id             end_station_name  \
# 0                  Eckhart Park               86  Lincoln Ave & Diversey Pkwy
# 1     Drake Ave & Fullerton Ave              503              Kosciuszko Park
# 2          McClurg Ct & Erie St              142   Indiana Ave & Roosevelt Rd
# 3  California Ave & Division St              216       Wood St & Augusta Blvd
# 4          Rush St & Hubbard St              125   Sheridan Rd & Lawrence Ave
#
# ...

# %%
#graphing ride start locations colored by demographic data - By Brandon Wolmer
#also including a kde plot of ride density

fig, axes = plt.subplots(2, 2, figsize=(18, 14))

sns.kdeplot(data=divvy_2020,x='start_lng',y='start_lat',fill=True,cmap='coolwarm',alpha=.6,levels=100,bw_adjust=2,ax=axes[0,0])
axes[0,0].set_title('Ride Density (KDE)', fontsize=11)
chi.plot(ax=axes[0,0],facecolor='none', edgecolor='black',linewidth=0.8)



sns.scatterplot(data=divvy_2020, x='start_lng',y='start_lat',hue='tax bracket', alpha=0.7,s=11,ax=axes[0,1], palette= 'tab20', linewidth=0)
axes[0,1].set_title('Ride Starts by Income Bracket', fontsize=11)
axes[0,1].legend(loc='upper left',bbox_to_anchor=(1.02, 1),fontsize=8)
chi.plot(ax=axes[0,1],facecolor='none', edgecolor='black',linewidth=0.5, alpha=0.5)



sns.scatterplot(data=divvy_2020, x='start_lng',y='start_lat',hue='majority_race',  alpha=0.7,s=11,ax=axes[1,0], palette= 'Dark2', linewidth=0)
axes[1,0].set_title('Ride Starts by Majority Race', fontsize=11)
axes[1,0].legend(loc='upper left',bbox_to_anchor=(1.02, 1),fontsize=8)
chi.plot(ax=axes[1,0],facecolor='none', edgecolor='black',linewidth=0.5, alpha=0.5)



sns.scatterplot(data=divvy_2020, x='start_lng',y='start_lat',hue='Majority_age_group',  alpha=0.9,s=11,ax=axes[1,1], palette= 'Pastel1', linewidth=0)
axes[1,1].set_title('Ride Starts by Majority Age Group', fontsize=11)
axes[1,1].legend(loc='upper left',bbox_to_anchor=(1.02, 1),fontsize=8)
chi.plot(ax=axes[1,1],facecolor='none', edgecolor='black',linewidth=0.5, alpha=0.5)



fig.suptitle('Divvy 2020 Ride Patterns and Neighborhood Demographics', fontsize=14, y=0.98)

plt.tight_layout(rect=[0, 0, 0.82, 0.95],pad=3)
plt.show()

# %% [markdown]
# ## Other sections

# %% [markdown]
# Put code with comments. The comments should explain the code such that it can be easily understood. You may put text *(in a markdown cell)* before a large chunk of code to explain the overall purpose of the code, if it is not intuitive. **Put the name of the person / persons who contributed to each code chunk / set of code chunks.**
#
# Put each model in a section of its name and mention the name of the team-member tuning the model. Below is an example:

# %% [markdown]
# ## Conclusions and Recommendations to stakeholder(s)
#
# You may or may not have code to put in this section. Delete this section if it is irrelevant.
