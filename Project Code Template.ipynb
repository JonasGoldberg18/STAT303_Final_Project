# %% [raw]
# ---
# title: "Project Code"
# subtitle: Team name
# author: Author 1, Author 2, Author 3, and Author 4
# date: 12/09/2025
# number-sections: true
# abstract: _This file contains the code for the project on <>, as part of the STAT303-1-Sec20&21 course in Fall 2024_.
# format:
#   html:
#     toc: true
#     toc-title: Contents
#     self-contained: true
#     font-size: 100%
#     toc-depth: 4
#     mainfont: serif
# jupyter: python3
# ---

# %% [markdown]
# ## Length of the code {-}
# No restriction
#
# **Delete this section from the report, when using this template.**

# %% [markdown]
# ## Data quality check / cleaning / preparation
#
# Put code with comments. The comments should explain the code such that it can be easily understood. You may put text *(in a markdown cell)* before a large chunk of code to explain the overall purpose of the code, if it is not intuitive. **Put the name of the person / persons who contributed to each code chunk / set of code chunks.** An example is given below.

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from shapely.geometry import Point
import geopandas as gpd

# %matplotlib inline

# %%
april2020 = pd.read_csv("../data/202004-divvy-tripdata.csv")
may2020 = pd.read_csv("../data/202005-divvy-tripdata.csv")
june2020 = pd.read_csv("../data/202006-divvy-tripdata.csv")
july2020 = pd.read_csv("../data/202007-divvy-tripdata.csv")
august2020 = pd.read_csv("../data/202008-divvy-tripdata.csv")
september2020 = pd.read_csv("../data/202009-divvy-tripdata.csv")
october2020 = pd.read_csv("../data/202010-divvy-tripdata.csv")
novemeber2020 = pd.read_csv("../data/202011-divvy-tripdata.csv")
december2020 = pd.read_csv("../data/202012-divvy-tripdata.csv")
january2021 = pd.read_csv("../data/202101-divvy-tripdata.csv")
february2021 = pd.read_csv("../data/202102-divvy-tripdata.csv")
march2021 = pd.read_csv("../data/202103-divvy-tripdata.csv")
april2021 = pd.read_csv("../data/202104-divvy-tripdata.csv")
may2021 = pd.read_csv("../data/202105-divvy-tripdata.csv")
june2021 = pd.read_csv("../data/202106-divvy-tripdata.csv")
july2021 = pd.read_csv("../data/202107-divvy-tripdata.csv")
august2021 = pd.read_csv("../data/202108-divvy-tripdata.csv")
september2021 = pd.read_csv("../data/202109-divvy-tripdata.csv")
october2021 = pd.read_csv("../data/202110-divvy-tripdata.csv")
novemeber2021 = pd.read_csv("../data/202111-divvy-tripdata.csv")
december2021 = pd.read_csv("../data/202112-divvy-tripdata.csv")
january2022 = pd.read_csv("../data/202201-divvy-tripdata.csv")
february2022 = pd.read_csv("../data/202202-divvy-tripdata.csv")
march2022 = pd.read_csv("../data/202203-divvy-tripdata.csv")
april2022 = pd.read_csv("../data/202204-divvy-tripdata.csv")
may2022 = pd.read_csv("../data/202205-divvy-tripdata.csv")
june2022 = pd.read_csv("../data/202206-divvy-tripdata.csv")
july2022 = pd.read_csv("../data/202207-divvy-tripdata.csv")
august2022 = pd.read_csv("../data/202208-divvy-tripdata.csv")
september2022 = pd.read_csv("../data/202209-divvy-tripdata.csv")
october2022 = pd.read_csv("../data/202210-divvy-tripdata.csv")
novemeber2022 = pd.read_csv("../data/202211-divvy-tripdata.csv")
december2022 = pd.read_csv("../data/202212-divvy-tripdata.csv")
january2023 = pd.read_csv("../data/202301-divvy-tripdata.csv")
february2023 = pd.read_csv("../data/202302-divvy-tripdata.csv")
march2023 = pd.read_csv("../data/202303-divvy-tripdata.csv")
april2023 = pd.read_csv("../data/202304-divvy-tripdata.csv")
may2023 = pd.read_csv("../data/202305-divvy-tripdata.csv")
june2023 = pd.read_csv("../data/202306-divvy-tripdata.csv")
july2023 = pd.read_csv("../data/202307-divvy-tripdata.csv")
august2023 = pd.read_csv("../data/202308-divvy-tripdata.csv")
september2023 = pd.read_csv("../data/202309-divvy-tripdata.csv")
october2023 = pd.read_csv("../data/202310-divvy-tripdata.csv")
novemeber2023 = pd.read_csv("../data/202311-divvy-tripdata.csv")
december2023 = pd.read_csv("../data/202312-divvy-tripdata.csv")
january2024 = pd.read_csv("../data/202401-divvy-tripdata.csv")
february2024 = pd.read_csv("../data/202402-divvy-tripdata.csv")
march2024 = pd.read_csv("../data/202403-divvy-tripdata.csv")
april2024 = pd.read_csv("../data/202404-divvy-tripdata.csv")
may2024 = pd.read_csv("../data/202405-divvy-tripdata.csv")
june2024 = pd.read_csv("../data/202406-divvy-tripdata.csv")
july2024 = pd.read_csv("../data/202407-divvy-tripdata.csv")
august2024 = pd.read_csv("../data/202408-divvy-tripdata.csv")
september2024 = pd.read_csv("../data/202409-divvy-tripdata.csv")
october2024 = pd.read_csv("../data/202410-divvy-tripdata.csv")
novemeber2024 = pd.read_csv("../data/202411-divvy-tripdata.csv")
december2024 = pd.read_csv("../data/202412-divvy-tripdata.csv")
january2025 = pd.read_csv("../data/202501-divvy-tripdata.csv")
february2025 = pd.read_csv("../data/202502-divvy-tripdata.csv")
march2025 = pd.read_csv("../data/202503-divvy-tripdata.csv")
april2025 = pd.read_csv("../data/202504-divvy-tripdata.csv")
may2025 = pd.read_csv("../data/202505-divvy-tripdata.csv")
june2025 = pd.read_csv("../data/202506-divvy-tripdata.csv")
july2025 = pd.read_csv("../data/202507-divvy-tripdata.csv")
august2025 = pd.read_csv("../data/202508-divvy-tripdata.csv")
september2025 = pd.read_csv("../data/202509-divvy-tripdata.csv")
october2025 = pd.read_csv("../data/202510-divvy-tripdata.csv")

# %%
divvy_data_2020 = pd.concat([april2020, may2020, june2020, july2020, august2020, september2020, october2020, novemeber2020, december2020])
divvy_data_2021 = pd.concat([january2021, february2021, march2021, april2021, may2021, june2021, july2021, august2021, september2021, october2021, novemeber2021, december2021])
divvy_data_2022 = pd.concat([january2022, february2022, march2022, april2022, may2022, june2022, july2022, august2022, september2022, october2022, novemeber2022, december2022])
divvy_data_2023 = pd.concat([january2023, february2023, march2023, april2023, may2023, june2023, july2023, august2023, september2023, october2023, novemeber2023, december2023])
divvy_data_2024 = pd.concat([january2024, february2024, march2024, april2024, may2024, june2024, july2024, august2024, september2024, october2024])

# %%
divvy_data = pd.concat([divvy_data_2020, divvy_data_2021, divvy_data_2022, divvy_data_2023, divvy_data_2024])

# %% [markdown]
# ### Distribution of variables
# *By Sylvia Sherwood*

# %%
#...Plot for distribution of variables...#

# %% [markdown]
# ### Data cleaning
# *By Sankaranarayanan Balasubramanian & Fiona Fe*

# %%
#...Code with comments...#

# Imputing missing values #

# %% [markdown]
# ### Data preparation
# *By Ryu Kimiko*

# %%
######---------------Creating new variables----------------#########

#Creating number of bedrooms per unit floor area

#Creating ratio of bathrooms to bedrooms

#Creating ratio of carpet area to floor area

# %%
######-----Standardizing the dataset ----------------------#########

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# Put code with comments. The comments should explain the code such that it can be easily understood. You may put text *(in a markdown cell)* before a large chunk of code to explain the overall purpose of the code, if it is not intuitive. **Put the name of the person / persons who contributed to each code chunk / set of code chunks.**

# %% [markdown]
# ### Analysis 1
# *By \<Name of person doing the analysis>*

# %% [markdown]
# ### Analysis 2
# *By \<Name of person doing the analysis>*

# %% [markdown]
# ### Analysis 3
# *By \<Name of person doing the analysis>*

# %% [markdown]
# ### Analysis 4
# *By \<Name of person doing the analysis>*

# %% [markdown]
# ## Other sections

# %% [markdown]
# Put code with comments. The comments should explain the code such that it can be easily understood. You may put text *(in a markdown cell)* before a large chunk of code to explain the overall purpose of the code, if it is not intuitive. **Put the name of the person / persons who contributed to each code chunk / set of code chunks.**
#
# Put each model in a section of its name and mention the name of the team-member tuning the model. Below is an example:

# %% [markdown]
# ## Conclusions and Recommendations to stakeholder(s)
#
# You may or may not have code to put in this section. Delete this section if it is irrelevant.
