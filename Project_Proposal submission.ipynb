# %% [raw]
# ---
# title: "Project proposal"
# format:
#   html:
#     toc: true
#     toc-title: Contents
#     code-fold: show
#     self-contained: true
# jupyter: python3
# ---

# %% [markdown]
# ## Instructions {-}
#
# 1. Please answer the following questions as part of your project proposal.
#
# 2. Write your answers in the *Markdown* cells of the Jupyter notebook. You don't need to write any code, but if you want to, you may use the *Code* cells.
#
# 3. Use [Quarto](https://quarto.org/docs/output-formats/html-basics.html) to print the *.ipynb* file as HTML. You will need to open the command prompt, navigate to the directory containing the file, and use the command: `quarto render filename.ipynb --to html`. Submit the HTML file.
#
# 4. The project proposal is worth 1 point1, and is due on **14th Nov 2025 at 11:59 pm**.
#
# 5. You must make one submission as a group, and not individually.
#
# 6. Maintaining a GitHub repository is optional, though encouraged for the project.
#
# 7. Share the link of your project’s GitHub repository on the [spreadsheet](https://docs.google.com/spreadsheets/d/1C_H3bDKBAQnUJfbUzNrT0tus-96P-tEN/edit?usp=sharing&ouid=102488148453078668645&rtpof=true&sd=true).

# %% [markdown]
# # 1) Team name
# Mention your team name.
#
# *(0 points)*

# %% [markdown]
# VS Code

# %% [markdown]
# # 2) Member names
# Mention the names of your team members.
#
# *(0 points)*

# %% [markdown]
# Rebecca Lazarus, Victoria Yu, Jonas Goldberg, Brandon Wolmer

# %% [markdown]
# # 3) EDA (Exploratory data analysis) questions
#
# Explain the questions to be answered in your course project, one for each team member. Mention the name of the team member and the question that they will answer against it.
#
# *(0.4 points)*

# %% [markdown]
# Jonas Goldberg - What factors influence the likelihood of a ride being requested? To elaborate, does the time of day and location influence the likelihood of a ride being requested? Are there correlations with high/low volumes of ride requests and the time of year? Lastly, how do rides being requested relate to Chicago traffic congestion?
#
# Rebecca Lazarus - How have divvy bike ridership trends compared to CTA ridership over recent years? Are these two forms of public transport competitors? Do ridership trends differ based on the distance/length of ride?
#
# Victoria Yu - What economic qualities of a community around divvy bike docks boost ridership? What are some communities around the Chicago area that show similar qualities and will benefit from having more divvy bike docks?
#
# Brandon Wolmer - How do demographic characteristics of Chicago neighborhoods relate to Divvy bike user patterns, including trip frequency, trip duration, and the proportion of member riders versus casual riders? How do gender differences in Divvy bike usage change across neighborhoods with different family income profiles, and how does proximity to transportation affect these patterns?

# %% [markdown]
# # 4) Data
#
# What data sources will you use, please share the link of the data, and how will the data help answer the questions? Explain.
#
# If you are using multiple datasets, please provide the information for each dataset.
#
#
# *(0.4 points)*

# %% [markdown]
# All the questions will use the Divvy bike dataset https://divvy-tripdata.s3.amazonaws.com/index.html. Data from multiple different time periods will be used.
#
# The first question will be answered using the Divvy dataset and two datasets of historical congestion estimates by region in Chicago. One contains data from 2013-2018 and the other from 2018-present. The datasets are publicly available and can be found at the following two links:
# https://catalog.data.gov/dataset/chicago-traffic-tracker-historical-congestion-estimates-by-region-2018-current
# https://catalog.data.gov/dataset/chicago-traffic-tracker-historical-congestion-estimates-by-region-2013-2018
#
# The second question will use Divvy data as well as CTA data from the Chicago Datasets Portal. http://data.cityofchicago.org/dataset/CTA-Ridership-Daily-Boarding-Totals/6iiy-9s97. This dataset will be compared to the Divvy dataset to get a sense of overall ridership trends for both the CTA and Divvy Bikes as well as how those trends may relate to  one another.
#
# The third question will use the Divvy dataset from 2016-2025 as well as the https://data.cityofchicago.org/d/4dpw-9rts Micro-Market Recovery Program - Permits, https://chicagohealthatlas.org/indicators/POP?topic=population and the https://data.cityofchicago.org/d/uupf-x98q Business Licenses - Current Active. THe Divvy dataset will be used to find out what communities have the highest ridership and then use the other two datasets will be used to find out what qualities those communities have in common. Then, that information will be used to find other communities around Chicago that have similar qualities but do not have Divvy bike docks yet. This will help identify potential areas for Divvy bike dock expansion. The map will help visualize communities that are experiencing economic growth and may benefit from having Divvy bike docks.
#
# The fourth question will be answered using the Divvy dataset, information from the Census Dataset: https://data.census.gov/all?q=Chicago+city,+Illinois and potentially The Chicago Health Atlas: https://chicagohealthatlas.org/

# %% [markdown]
# # 5) Stakeholder

# %% [markdown]
# how will your project benefit the stakeholder? Explain.
#
# *(0.1 points)*

# %% [markdown]
# This project will provide a general understanding of how bike ridership has changed in response to the recent expansion. Additionally, we are planning to analyze which communities utilize the divvy bikes most to see if this expansion has reached its goal of providing racial equity and mobility across communities. This information can be used to assess future adjustments that should be made to the divvy program as well as track the progress that has already been made.
